# %%
# @title Make Always On
# %%html
<audio src="https://raw.githubusercontent.com/KoboldAI/KoboldAI-Client/main/colab/silence.m4a" autoplay loop controls hidden></audio>
# Out:
# <audio src="https://raw.githubusercontent.com/KoboldAI/KoboldAI-Client/main/colab/silence.m4a" autoplay loop controls hidden></audio>

# %%
# @title Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title Run Fooocus

# !pip install pygit2==1.15.1
# %cd /content/drive/MyDrive/
# !git clone https://github.com/naufal-backup/Fooocus.git
# %cd /content/drive/MyDrive/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 67.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.19.1
#     Uninstalling pygit2-1.19.1:
#       Successfully uninstalled pygit2-1.19.1
# ...
# /content/drive/MyDrive
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/drive/.shortcut-targets-by-id/1zHd-ENHjuc7oqYrCHwqr603Sh1p_wrO0/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
